# %%
from voice_agent_flow.apps.car_loan import create_agent_session
from voice_agent_flow.memory import Memory
import json

async def run_single(messages:list[dict]):
    memory = Memory.from_dict(messages)
    chat = create_agent_session()
    chat.set_agent("wechat_account_confirm")
    chat.set_memory(memory)
    _ = await chat._chat()
    events = chat.new_events
    output = events.get("output", "None")
    del events["output"]
    events = str(events)
    return output, events

# %%
messages = [
    {'role': 'assistant', 'content': '您好，请问是李明先生吗'},
    {'role': 'user', 'content': '是的，我是李明'},
    {'role': 'assistant', 'content': '请问您是来咨询车贷业务的吗？'},
    {'role': 'user', 'content': '加我微信聊吧'},
]

await run_single(messages)
# Out:
# 方便用您尾号xxxx的手机号加您的微信么？
# ('方便用您尾号xxxx的手机号加您的微信么？',
#  "{'new_messages': [AssistantMessage(role='assistant', timestamp='2026-02-27T11:39:42.964051', content='方便用您尾号xxxx的手机号加您的微信么？')], 'new_handoff': None}")
